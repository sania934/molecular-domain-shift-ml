# %%
import pandas as pd

qm9 = pd.read_csv("qm9_5k.csv")
hopv = pd.read_csv("hopv_clean_target_prop7.csv")

print(qm9.shape)
print(hopv.shape)
# Out:
# (5000, 21)
# (180, 4)

# %%
print(qm9.columns)
print(hopv.columns)
# Out:
# Index(['mol_id', 'smiles', 'A', 'B', 'C', 'mu', 'alpha', 'homo', 'lumo', 'gap',
#        'r2', 'zpve', 'u0', 'u298', 'h298', 'g298', 'cv', 'u0_atom',
#        'u298_atom', 'h298_atom', 'g298_atom'],
#       dtype='object')
# Index(['SMILES', 'prop_5', 'prop_6', 'prop_7'], dtype='object')

# %%
print(qm9.isnull().sum())
print(hopv.isnull().sum())
# Out:
# mol_id       0
# smiles       0
# A            0
# B            0
# C            0
# mu           0
# alpha        0
# homo         0
# lumo         0
# gap          0
# r2           0
# zpve         0
# u0           0
# u298         0
# h298         0
# g298         0
# cv           0
# u0_atom      0
# u298_atom    0
# h298_atom    0
# g298_atom    0
# dtype: int64
# SMILES    0
# prop_5    0
# prop_6    0
# prop_7    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(qm9["gap"], bins=50)
plt.title("QM9 Band Gap Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(hopv["prop_7"], bins=50)
plt.title("HOPV Property 7 Distribution")
plt.show()
