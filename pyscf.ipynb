# %% [markdown]
# <a href="https://colab.research.google.com/github/sania934/molecular-domain-shift-ml/blob/main/pyscf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyscf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 MB 26.8 MB/s eta 0:00:00
# ...
