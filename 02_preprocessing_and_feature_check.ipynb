# %%
import pandas as pd

qm9 = pd.read_csv("qm9_5k.csv")
hopv = pd.read_csv("hopv_clean_target_prop7.csv")

print(qm9.shape)
print(hopv.shape)
# Out:
# (5000, 21)
# (180, 4)

# %%
qm9["gap"] = qm9["lumo"] - qm9["homo"]
hopv["prop_7"] = hopv["prop_6"] - hopv["prop_5"]

# %%
qm9 = qm9[["smiles", "gap"]]
hopv = hopv[["SMILES", "prop_7"]]
